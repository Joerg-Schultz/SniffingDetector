# %%
run_name = "three neurons, 80 Dense"
description = "Increased the number of neurons in the hidden layer to 80"
data_version = "0" # only to tell IDE that version is a viable
# %store -r data_version
# data_version = "dv1" # if you want to force a specific version

data_classes = ["Sniffing", "Background", "Quiet"]
correct_class_imbalance = True
epochs = 200
validation_fraction = 0.2

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout
import tensorflow_io as tfio
import tensorflow.experimental.numpy as tnp
from tensorflow.python.ops import gen_audio_ops as audio_ops
import os
import mlflow
#  enable NumPy behavior for TensorFlow:
tnp.experimental_enable_numpy_behavior()

# %%
def generate_spectrogram(file_path, label):
    # does not scale as sniffing should be the same independent of background level
    audio_tensor = tfio.audio.AudioIOTensor(file_path, dtype=tf.int16)
    audio = tf.cast(audio_tensor[:], tf.float32)
    spectrogram = audio_ops.audio_spectrogram(audio,
                                              window_size=320,
                                              stride=160,
                                              magnitude_squared=True)
    spectrogram = tf.nn.pool(
        input=tf.expand_dims(spectrogram, -1),
        window_shape=[1, 6],
        strides=[1, 6],
        pooling_type='AVG',
        padding='SAME')
    spectrogram = tf.squeeze(spectrogram, axis=0)
    # Not sure whether the log is a good idea...
    spectrogram = tnp.log10(spectrogram + 1e-6)
    return spectrogram, label

def prepare_data(dir, value):
    filePath = os.path.join(dir, "*.wav")
    files = tf.data.Dataset.list_files(filePath)
    file_count = len(files)
    #values = tf.zeros(len(files)) if value == 0 else tf.ones(len(files))
    # First neuron for Sniffing
    if value == 0:
        values = tf.concat([tf.ones(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1])], axis=1)
    elif value == 1:
        values = tf.concat([tf.zeros(shape=[file_count, 1]), tf.ones(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1])], axis=1)
    elif value == 2:
        values = tf.concat([tf.zeros(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1]), tf.ones(shape=[file_count, 1])], axis=1)

    data = tf.data.Dataset.zip((files, tf.data.Dataset.from_tensor_slices(values)))
    spectrogramData = data.map(generate_spectrogram)
    return spectrogramData

def generate_dataset(train_or_test, classes):
    class_counts = []
    data_sets = []
    for index, current_class in enumerate(classes):
        current_data_dir = f"data/{train_or_test}/{current_class}"
        current_data = prepare_data(current_data_dir, index)
        data_sets.append(current_data)
        current_number = current_data.cardinality().numpy()
        class_counts.append(current_number)
        print(f"{current_class} Datasets: {current_number}")

    if correct_class_imbalance:
        smallest_data_count = min(class_counts)
        for index, data_set in enumerate(data_sets):
            corrected_data = data_set.shuffle(class_counts[index]).take(smallest_data_count)
            data_sets[index] = corrected_data
            corrected_number = corrected_data.cardinality().numpy()
            print(f"Corrected {classes[index]} Datasets: {corrected_number}")
    combined_data = data_sets[0]
    for next_data in data_sets[1:]:
        combined_data = combined_data.concatenate(next_data)
    combined_data = combined_data.cache()
    return combined_data.shuffle(buffer_size=combined_data.cardinality().numpy())

def split_validation(allData, fraction):
    numberDataSets = allData.cardinality().numpy()
    validationCount = round(numberDataSets * fraction)
    trainSet = allData.take(numberDataSets - validationCount)
    validationSet = allData.skip(numberDataSets - validationCount).take(validationCount)
    return trainSet, validationSet

def batch_prefetch(dataSet):
    dataSet = dataSet.batch(16)
    dataSet = dataSet.prefetch(8)
    return dataSet

def representative_data_gen():
    repr_samples, repr_labels = train.as_numpy_iterator().next()
    yield [repr_samples]

# %%
data = generate_dataset("train", data_classes)
train, validation = split_validation(data, validation_fraction)
train = batch_prefetch(train)
validation = batch_prefetch(validation)
samples, labels = train.as_numpy_iterator().next()
inputShape = samples.shape[1:]
print(f"inputShape {inputShape}")
# Out:
# Sniffing Datasets: 261
# Background Datasets: 765
# Quiet Datasets: 233
# Corrected Sniffing Datasets: 233
# Corrected Background Datasets: 233
# Corrected Quiet Datasets: 233
# inputShape (99, 43, 1)

# %%
# need the run id to log into same run over different cells
with mlflow.start_run(run_name=run_name) as run:
    run_id = run.info.run_id
    mlflow.tensorflow.autolog()
    mlflow.log_param("data_version", data_version)
    mlflow.log_param("data classes", data_classes)
    mlflow.log_param("validation fraction", validation_fraction)
    mlflow.log_param("correct class imbalance", correct_class_imbalance)
    mlflow.log_param("Description", description)

# %%
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    model = Sequential([
        Conv2D(4, 3,
               padding='same',
               activation='relu',
               kernel_regularizer=regularizers.l2(0.001),
               name='conv_layer1',
               input_shape=inputShape),
        MaxPooling2D(name='max_pooling1', pool_size=(2,2)),
        Conv2D(4, 3,
               padding='same',
               activation='relu',
               kernel_regularizer=regularizers.l2(0.001),
               name='conv_layer2'),
        MaxPooling2D(name='max_pooling2', pool_size=(2,2)),
        Flatten(),
        Dropout(0.2),
        Dense(
            40,
            activation='relu',
            kernel_regularizer=regularizers.l2(0.001),
            name='hidden_layer1'
        ),
        Dense(
            3,
            activation='softmax',
            kernel_regularizer=regularizers.l2(0.001),
            name='output'
        )
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=[[tf.keras.metrics.Recall(),tf.keras.metrics.Precision()]])

    model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_layer1 (Conv2D)        (None, 99, 43, 4)         40
#
#  max_pooling1 (MaxPooling2D)  (None, 49, 21, 4)        0
#
#  conv_layer2 (Conv2D)        (None, 49, 21, 4)         148
#
#  max_pooling2 (MaxPooling2D)  (None, 24, 10, 4)        0
#
#  flatten (Flatten)           (None, 960)               0
#
#  dropout (Dropout)           (None, 960)               0
#
#  hidden_layer1 (Dense)       (None, 40)                38440
#
#  output (Dense)              (None, 3)                 123
#
# =================================================================
# Total params: 38,751
# Trainable params: 38,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    hist = model.fit(train, epochs=epochs, validation_data=validation)
# Out:
# Epoch 1/200
# 35/35 [==============================] - 9s 106ms/step - loss: 0.6858 - recall: 0.0948 - precision: 0.4690 - val_loss: 0.5994 - val_recall: 0.0857 - val_precision: 1.0000
# Epoch 2/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.5511 - recall: 0.4275 - precision: 0.7177 - val_loss: 0.4918 - val_recall: 0.6500 - val_precision: 0.7712
# Epoch 3/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.4761 - recall: 0.5921 - precision: 0.7103 - val_loss: 0.3919 - val_recall: 0.7286 - val_precision: 0.7846
# Epoch 4/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.4258 - recall: 0.6601 - precision: 0.7193 - val_loss: 0.3932 - val_recall: 0.6857 - val_precision: 0.7742
# Epoch 5/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.4114 - recall: 0.6905 - precision: 0.7311 - val_loss: 0.4229 - val_recall: 0.6214 - val_precision: 0.6304
# Epoch 6/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.3920 - recall: 0.6941 - precision: 0.7225 - val_loss: 0.4005 - val_recall: 0.6714 - val_precision: 0.7015
# Epoch 7/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.3804 - recall: 0.7084 - precision: 0.7347 - val_loss: 0.3136 - val_recall: 0.7357 - val_precision: 0.7687
# Epoch 8/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.3774 - recall: 0.7013 - precision: 0.7232 - val_loss: 0.3503 - val_recall: 0.7714 - val_precision: 0.7826
# Epoch 9/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.3633 - recall: 0.7513 - precision: 0.7706 - val_loss: 0.3175 - val_recall: 0.8071 - val_precision: 0.8188
# Epoch 10/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.3446 - recall: 0.7549 - precision: 0.7645 - val_loss: 0.3511 - val_recall: 0.7714 - val_precision: 0.7826
# Epoch 11/200
# 35/35 [==============================] - 3s 75ms/step - loss: 0.3353 - recall: 0.7764 - precision: 0.7862 - val_loss: 0.3184 - val_recall: 0.7929 - val_precision: 0.8043
# Epoch 12/200
# 35/35 [==============================] - 3s 78ms/step - loss: 0.3456 - recall: 0.7710 - precision: 0.7780 - val_loss: 0.2743 - val_recall: 0.8286 - val_precision: 0.8345
# Epoch 13/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.3308 - recall: 0.7710 - precision: 0.7794 - val_loss: 0.2923 - val_recall: 0.8286 - val_precision: 0.8406
# Epoch 14/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.3300 - recall: 0.7871 - precision: 0.7928 - val_loss: 0.2855 - val_recall: 0.8286 - val_precision: 0.8345
# Epoch 15/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.3397 - recall: 0.7674 - precision: 0.7730 - val_loss: 0.3223 - val_recall: 0.7571 - val_precision: 0.7737
# Epoch 16/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.3243 - recall: 0.7871 - precision: 0.8000 - val_loss: 0.3072 - val_recall: 0.8643 - val_precision: 0.8768
# Epoch 17/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2942 - recall: 0.8211 - precision: 0.8315 - val_loss: 0.2648 - val_recall: 0.9000 - val_precision: 0.9000
# Epoch 18/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.3006 - recall: 0.8104 - precision: 0.8118 - val_loss: 0.2811 - val_recall: 0.8714 - val_precision: 0.8714
# Epoch 19/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.3032 - recall: 0.8211 - precision: 0.8255 - val_loss: 0.2633 - val_recall: 0.8429 - val_precision: 0.8429
# Epoch 20/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.3042 - recall: 0.8086 - precision: 0.8144 - val_loss: 0.2788 - val_recall: 0.8429 - val_precision: 0.8489
# Epoch 21/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.3023 - recall: 0.8247 - precision: 0.8262 - val_loss: 0.2507 - val_recall: 0.8643 - val_precision: 0.8705
# Epoch 22/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2899 - recall: 0.8014 - precision: 0.8043 - val_loss: 0.2654 - val_recall: 0.8786 - val_precision: 0.8786
# Epoch 23/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.2822 - recall: 0.8444 - precision: 0.8505 - val_loss: 0.2644 - val_recall: 0.8786 - val_precision: 0.8849
# Epoch 24/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2960 - recall: 0.8211 - precision: 0.8241 - val_loss: 0.2634 - val_recall: 0.8857 - val_precision: 0.8921
# Epoch 25/200
# 35/35 [==============================] - 3s 78ms/step - loss: 0.2717 - recall: 0.8479 - precision: 0.8525 - val_loss: 0.2276 - val_recall: 0.8714 - val_precision: 0.8714
# Epoch 26/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2731 - recall: 0.8247 - precision: 0.8336 - val_loss: 0.2792 - val_recall: 0.8500 - val_precision: 0.8500
# Epoch 27/200
# 35/35 [==============================] - 3s 75ms/step - loss: 0.2762 - recall: 0.8372 - precision: 0.8387 - val_loss: 0.2023 - val_recall: 0.9286 - val_precision: 0.9286
# Epoch 28/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.2882 - recall: 0.8301 - precision: 0.8345 - val_loss: 0.2705 - val_recall: 0.8429 - val_precision: 0.8429
# Epoch 29/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2979 - recall: 0.8211 - precision: 0.8241 - val_loss: 0.2432 - val_recall: 0.9000 - val_precision: 0.9000
# Epoch 30/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2648 - recall: 0.8479 - precision: 0.8479 - val_loss: 0.2448 - val_recall: 0.9071 - val_precision: 0.9071
# Epoch 31/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2712 - recall: 0.8301 - precision: 0.8345 - val_loss: 0.2445 - val_recall: 0.8929 - val_precision: 0.8929
# Epoch 32/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2892 - recall: 0.8229 - precision: 0.8244 - val_loss: 0.2403 - val_recall: 0.9214 - val_precision: 0.9214
# Epoch 33/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2807 - recall: 0.8301 - precision: 0.8360 - val_loss: 0.2363 - val_recall: 0.8786 - val_precision: 0.8786
# Epoch 34/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2667 - recall: 0.8426 - precision: 0.8471 - val_loss: 0.2508 - val_recall: 0.8857 - val_precision: 0.8857
# Epoch 35/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2701 - recall: 0.8444 - precision: 0.8489 - val_loss: 0.2536 - val_recall: 0.8286 - val_precision: 0.8286
# Epoch 36/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2892 - recall: 0.8229 - precision: 0.8229 - val_loss: 0.2973 - val_recall: 0.8357 - val_precision: 0.8357
# Epoch 37/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2978 - recall: 0.8086 - precision: 0.8129 - val_loss: 0.2424 - val_recall: 0.8929 - val_precision: 0.8929
# Epoch 38/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2620 - recall: 0.8408 - precision: 0.8423 - val_loss: 0.2336 - val_recall: 0.9286 - val_precision: 0.9353
# Epoch 39/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.2645 - recall: 0.8408 - precision: 0.8408 - val_loss: 0.2255 - val_recall: 0.9071 - val_precision: 0.9071
# Epoch 40/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2726 - recall: 0.8247 - precision: 0.8276 - val_loss: 0.2747 - val_recall: 0.8071 - val_precision: 0.8188
# Epoch 41/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2703 - recall: 0.8157 - precision: 0.8172 - val_loss: 0.2116 - val_recall: 0.9071 - val_precision: 0.9071
# Epoch 42/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2832 - recall: 0.8229 - precision: 0.8244 - val_loss: 0.2452 - val_recall: 0.8571 - val_precision: 0.8571
# Epoch 43/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.2689 - recall: 0.8336 - precision: 0.8366 - val_loss: 0.2058 - val_recall: 0.9071 - val_precision: 0.9071
# Epoch 44/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2644 - recall: 0.8354 - precision: 0.8369 - val_loss: 0.2109 - val_recall: 0.8857 - val_precision: 0.8857
# Epoch 45/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2547 - recall: 0.8605 - precision: 0.8620 - val_loss: 0.2966 - val_recall: 0.7857 - val_precision: 0.7971
# Epoch 46/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2496 - recall: 0.8784 - precision: 0.8799 - val_loss: 0.2037 - val_recall: 0.9214 - val_precision: 0.9214
# Epoch 47/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.2510 - recall: 0.8515 - precision: 0.8530 - val_loss: 0.2025 - val_recall: 0.9286 - val_precision: 0.9286
# Epoch 48/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.2608 - recall: 0.8444 - precision: 0.8444 - val_loss: 0.2899 - val_recall: 0.8071 - val_precision: 0.8129
# Epoch 49/200
# 35/35 [==============================] - 3s 75ms/step - loss: 0.2636 - recall: 0.8587 - precision: 0.8633 - val_loss: 0.1992 - val_recall: 0.9071 - val_precision: 0.9071
# Epoch 50/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2442 - recall: 0.8676 - precision: 0.8676 - val_loss: 0.2019 - val_recall: 0.9286 - val_precision: 0.9286
# Epoch 51/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2214 - recall: 0.8909 - precision: 0.8941 - val_loss: 0.1953 - val_recall: 0.9500 - val_precision: 0.9500
# Epoch 52/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2460 - recall: 0.8515 - precision: 0.8577 - val_loss: 0.2112 - val_recall: 0.9143 - val_precision: 0.9275
# Epoch 53/200
# 35/35 [==============================] - 2s 72ms/step - loss: 0.2559 - recall: 0.8551 - precision: 0.8551 - val_loss: 0.2170 - val_recall: 0.8714 - val_precision: 0.8714
# Epoch 54/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2389 - recall: 0.8712 - precision: 0.8743 - val_loss: 0.1969 - val_recall: 0.9429 - val_precision: 0.9429
# Epoch 55/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2480 - recall: 0.8587 - precision: 0.8602 - val_loss: 0.1772 - val_recall: 0.9500 - val_precision: 0.9500
# Epoch 56/200
# 35/35 [==============================] - 3s 84ms/step - loss: 0.2224 - recall: 0.8873 - precision: 0.8873 - val_loss: 0.1931 - val_recall: 0.9214 - val_precision: 0.9281
# Epoch 57/200
# 35/35 [==============================] - 4s 101ms/step - loss: 0.2520 - recall: 0.8408 - precision: 0.8484 - val_loss: 0.2070 - val_recall: 0.9286 - val_precision: 0.9286
# Epoch 58/200
# 35/35 [==============================] - 5s 131ms/step - loss: 0.2357 - recall: 0.8730 - precision: 0.8761 - val_loss: 0.1643 - val_recall: 0.9643 - val_precision: 0.9643
# Epoch 59/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.2236 - recall: 0.8891 - precision: 0.8891 - val_loss: 0.2234 - val_recall: 0.8643 - val_precision: 0.8643
# Epoch 60/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.2156 - recall: 0.8837 - precision: 0.8853 - val_loss: 0.1604 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 61/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.2107 - recall: 0.8927 - precision: 0.8991 - val_loss: 0.1626 - val_recall: 0.9357 - val_precision: 0.9357
# Epoch 62/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.2017 - recall: 0.9088 - precision: 0.9120 - val_loss: 0.1552 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 63/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2133 - recall: 0.8909 - precision: 0.8941 - val_loss: 0.1650 - val_recall: 0.9429 - val_precision: 0.9429
# Epoch 64/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1981 - recall: 0.9106 - precision: 0.9122 - val_loss: 0.2559 - val_recall: 0.8214 - val_precision: 0.8214
# Epoch 65/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.2521 - recall: 0.8623 - precision: 0.8685 - val_loss: 0.2362 - val_recall: 0.8786 - val_precision: 0.8786
# Epoch 66/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2132 - recall: 0.8945 - precision: 0.8945 - val_loss: 0.1596 - val_recall: 0.9643 - val_precision: 0.9643
# Epoch 67/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.2095 - recall: 0.8927 - precision: 0.8927 - val_loss: 0.1468 - val_recall: 0.9214 - val_precision: 0.9214
# Epoch 68/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1957 - recall: 0.9034 - precision: 0.9034 - val_loss: 0.1793 - val_recall: 0.9571 - val_precision: 0.9571
# Epoch 69/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1827 - recall: 0.9231 - precision: 0.9231 - val_loss: 0.1560 - val_recall: 0.9429 - val_precision: 0.9429
# Epoch 70/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1929 - recall: 0.9177 - precision: 0.9194 - val_loss: 0.1852 - val_recall: 0.9286 - val_precision: 0.9286
# Epoch 71/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1976 - recall: 0.8998 - precision: 0.9014 - val_loss: 0.1716 - val_recall: 0.9357 - val_precision: 0.9357
# Epoch 72/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1996 - recall: 0.9034 - precision: 0.9034 - val_loss: 0.1508 - val_recall: 0.9643 - val_precision: 0.9643
# Epoch 73/200
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1965 - recall: 0.9070 - precision: 0.9070 - val_loss: 0.1405 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 74/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.1907 - recall: 0.9141 - precision: 0.9141 - val_loss: 0.1482 - val_recall: 0.9571 - val_precision: 0.9571
# Epoch 75/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.2031 - recall: 0.8962 - precision: 0.8962 - val_loss: 0.1345 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 76/200
# 35/35 [==============================] - 2s 72ms/step - loss: 0.1803 - recall: 0.9213 - precision: 0.9213 - val_loss: 0.1086 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 77/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1808 - recall: 0.9320 - precision: 0.9320 - val_loss: 0.1562 - val_recall: 0.9571 - val_precision: 0.9571
# Epoch 78/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1878 - recall: 0.9123 - precision: 0.9140 - val_loss: 0.1477 - val_recall: 0.9500 - val_precision: 0.9500
# Epoch 79/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1846 - recall: 0.9141 - precision: 0.9174 - val_loss: 0.1289 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 80/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1875 - recall: 0.9159 - precision: 0.9159 - val_loss: 0.1139 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 81/200
# 35/35 [==============================] - 3s 86ms/step - loss: 0.1814 - recall: 0.9141 - precision: 0.9141 - val_loss: 0.1818 - val_recall: 0.9143 - val_precision: 0.9143
# Epoch 82/200
# 35/35 [==============================] - 3s 86ms/step - loss: 0.1921 - recall: 0.9213 - precision: 0.9213 - val_loss: 0.1177 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 83/200
# 35/35 [==============================] - 3s 99ms/step - loss: 0.1661 - recall: 0.9392 - precision: 0.9392 - val_loss: 0.1471 - val_recall: 0.9429 - val_precision: 0.9429
# Epoch 84/200
# 35/35 [==============================] - 4s 102ms/step - loss: 0.1791 - recall: 0.9213 - precision: 0.9213 - val_loss: 0.1429 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 85/200
# 35/35 [==============================] - 4s 108ms/step - loss: 0.1982 - recall: 0.9070 - precision: 0.9086 - val_loss: 0.1545 - val_recall: 0.9286 - val_precision: 0.9286
# Epoch 86/200
# 35/35 [==============================] - 3s 77ms/step - loss: 0.1923 - recall: 0.9159 - precision: 0.9159 - val_loss: 0.1377 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 87/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.1861 - recall: 0.9052 - precision: 0.9052 - val_loss: 0.1705 - val_recall: 0.9357 - val_precision: 0.9357
# Epoch 88/200
# 35/35 [==============================] - 4s 113ms/step - loss: 0.1771 - recall: 0.9213 - precision: 0.9229 - val_loss: 0.1482 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 89/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.1957 - recall: 0.9106 - precision: 0.9122 - val_loss: 0.1243 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 90/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.1692 - recall: 0.9338 - precision: 0.9355 - val_loss: 0.1224 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 91/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.1797 - recall: 0.9123 - precision: 0.9123 - val_loss: 0.1076 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 92/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.1459 - recall: 0.9535 - precision: 0.9535 - val_loss: 0.1066 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 93/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.1704 - recall: 0.9284 - precision: 0.9284 - val_loss: 0.1236 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 94/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.1652 - recall: 0.9374 - precision: 0.9374 - val_loss: 0.1583 - val_recall: 0.9500 - val_precision: 0.9500
# Epoch 95/200
# 35/35 [==============================] - 4s 105ms/step - loss: 0.1709 - recall: 0.9284 - precision: 0.9301 - val_loss: 0.1279 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 96/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.1570 - recall: 0.9410 - precision: 0.9427 - val_loss: 0.1009 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 97/200
# 35/35 [==============================] - 4s 101ms/step - loss: 0.1626 - recall: 0.9374 - precision: 0.9374 - val_loss: 0.1220 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 98/200
# 35/35 [==============================] - 4s 103ms/step - loss: 0.1628 - recall: 0.9428 - precision: 0.9444 - val_loss: 0.1161 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 99/200
# 35/35 [==============================] - 4s 126ms/step - loss: 0.1695 - recall: 0.9463 - precision: 0.9463 - val_loss: 0.1236 - val_recall: 0.9643 - val_precision: 0.9643
# Epoch 100/200
# 35/35 [==============================] - 3s 100ms/step - loss: 0.1814 - recall: 0.9213 - precision: 0.9213 - val_loss: 0.1130 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 101/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1664 - recall: 0.9374 - precision: 0.9391 - val_loss: 0.0980 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 102/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1923 - recall: 0.9123 - precision: 0.9140 - val_loss: 0.1694 - val_recall: 0.9500 - val_precision: 0.9500
# Epoch 103/200
# 35/35 [==============================] - 3s 75ms/step - loss: 0.1780 - recall: 0.9195 - precision: 0.9228 - val_loss: 0.1156 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 104/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.1584 - recall: 0.9338 - precision: 0.9338 - val_loss: 0.1177 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 105/200
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1471 - recall: 0.9535 - precision: 0.9535 - val_loss: 0.1062 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 106/200
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1501 - recall: 0.9481 - precision: 0.9498 - val_loss: 0.1079 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 107/200
# 35/35 [==============================] - 3s 86ms/step - loss: 0.1498 - recall: 0.9445 - precision: 0.9445 - val_loss: 0.1145 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 108/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1597 - recall: 0.9410 - precision: 0.9410 - val_loss: 0.1014 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 109/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1660 - recall: 0.9267 - precision: 0.9283 - val_loss: 0.1130 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 110/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.1494 - recall: 0.9517 - precision: 0.9517 - val_loss: 0.0905 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 111/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1493 - recall: 0.9463 - precision: 0.9463 - val_loss: 0.1140 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 112/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.1591 - recall: 0.9428 - precision: 0.9428 - val_loss: 0.1302 - val_recall: 0.9643 - val_precision: 0.9643
# Epoch 113/200
# 35/35 [==============================] - 3s 75ms/step - loss: 0.1423 - recall: 0.9624 - precision: 0.9624 - val_loss: 0.0920 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 114/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1591 - recall: 0.9410 - precision: 0.9410 - val_loss: 0.0996 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 115/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1521 - recall: 0.9463 - precision: 0.9463 - val_loss: 0.0934 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 116/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1438 - recall: 0.9571 - precision: 0.9588 - val_loss: 0.0991 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 117/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1322 - recall: 0.9589 - precision: 0.9589 - val_loss: 0.0993 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 118/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1393 - recall: 0.9571 - precision: 0.9571 - val_loss: 0.1662 - val_recall: 0.9214 - val_precision: 0.9214
# Epoch 119/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1526 - recall: 0.9481 - precision: 0.9481 - val_loss: 0.0958 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 120/200
# 35/35 [==============================] - 3s 77ms/step - loss: 0.1319 - recall: 0.9517 - precision: 0.9517 - val_loss: 0.1075 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 121/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1509 - recall: 0.9499 - precision: 0.9499 - val_loss: 0.0877 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 122/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1527 - recall: 0.9517 - precision: 0.9517 - val_loss: 0.0971 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 123/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1552 - recall: 0.9392 - precision: 0.9392 - val_loss: 0.1185 - val_recall: 0.9714 - val_precision: 0.9784
# Epoch 124/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1454 - recall: 0.9535 - precision: 0.9535 - val_loss: 0.1011 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 125/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1321 - recall: 0.9624 - precision: 0.9624 - val_loss: 0.0956 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 126/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.1278 - recall: 0.9678 - precision: 0.9678 - val_loss: 0.0998 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 127/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1364 - recall: 0.9571 - precision: 0.9571 - val_loss: 0.1185 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 128/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1331 - recall: 0.9606 - precision: 0.9606 - val_loss: 0.0899 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 129/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1461 - recall: 0.9517 - precision: 0.9534 - val_loss: 0.0795 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 130/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1341 - recall: 0.9660 - precision: 0.9660 - val_loss: 0.0906 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 131/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1311 - recall: 0.9660 - precision: 0.9660 - val_loss: 0.1025 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 132/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1518 - recall: 0.9499 - precision: 0.9499 - val_loss: 0.0981 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 133/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1478 - recall: 0.9463 - precision: 0.9463 - val_loss: 0.0801 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 134/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1203 - recall: 0.9714 - precision: 0.9714 - val_loss: 0.1015 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 135/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1399 - recall: 0.9517 - precision: 0.9517 - val_loss: 0.1062 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 136/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1652 - recall: 0.9499 - precision: 0.9499 - val_loss: 0.1053 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 137/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1429 - recall: 0.9535 - precision: 0.9535 - val_loss: 0.1027 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 138/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1369 - recall: 0.9517 - precision: 0.9517 - val_loss: 0.1102 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 139/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1332 - recall: 0.9678 - precision: 0.9678 - val_loss: 0.0856 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 140/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1360 - recall: 0.9589 - precision: 0.9589 - val_loss: 0.1052 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 141/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1343 - recall: 0.9589 - precision: 0.9589 - val_loss: 0.0819 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 142/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1204 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0846 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 143/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1070 - recall: 0.9803 - precision: 0.9803 - val_loss: 0.0926 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 144/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1479 - recall: 0.9445 - precision: 0.9445 - val_loss: 0.1016 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 145/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1159 - recall: 0.9696 - precision: 0.9713 - val_loss: 0.0881 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 146/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1197 - recall: 0.9714 - precision: 0.9714 - val_loss: 0.0938 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 147/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1270 - recall: 0.9660 - precision: 0.9677 - val_loss: 0.1017 - val_recall: 0.9786 - val_precision: 0.9786
# Epoch 148/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1342 - recall: 0.9589 - precision: 0.9606 - val_loss: 0.0935 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 149/200
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1220 - recall: 0.9660 - precision: 0.9660 - val_loss: 0.1029 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 150/200
# 35/35 [==============================] - 3s 85ms/step - loss: 0.1204 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0837 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 151/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1112 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0825 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 152/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.1295 - recall: 0.9678 - precision: 0.9678 - val_loss: 0.0816 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 153/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1151 - recall: 0.9785 - precision: 0.9785 - val_loss: 0.0801 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 154/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1339 - recall: 0.9571 - precision: 0.9571 - val_loss: 0.1232 - val_recall: 0.9714 - val_precision: 0.9714
# Epoch 155/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1406 - recall: 0.9553 - precision: 0.9553 - val_loss: 0.0988 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 156/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1370 - recall: 0.9571 - precision: 0.9571 - val_loss: 0.0884 - val_recall: 0.9857 - val_precision: 0.9857
# Epoch 157/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1303 - recall: 0.9606 - precision: 0.9606 - val_loss: 0.0919 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 158/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1101 - recall: 0.9839 - precision: 0.9839 - val_loss: 0.0817 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 159/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.1134 - recall: 0.9678 - precision: 0.9678 - val_loss: 0.0750 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 160/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1182 - recall: 0.9660 - precision: 0.9677 - val_loss: 0.0868 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 161/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1280 - recall: 0.9624 - precision: 0.9624 - val_loss: 0.0732 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 162/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1158 - recall: 0.9678 - precision: 0.9678 - val_loss: 0.0746 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 163/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1070 - recall: 0.9785 - precision: 0.9785 - val_loss: 0.0800 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 164/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1171 - recall: 0.9767 - precision: 0.9767 - val_loss: 0.0817 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 165/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.1230 - recall: 0.9785 - precision: 0.9785 - val_loss: 0.0765 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 166/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1156 - recall: 0.9696 - precision: 0.9696 - val_loss: 0.0763 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 167/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.1168 - recall: 0.9714 - precision: 0.9714 - val_loss: 0.0772 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 168/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1086 - recall: 0.9750 - precision: 0.9767 - val_loss: 0.0710 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 169/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1029 - recall: 0.9821 - precision: 0.9821 - val_loss: 0.0876 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 170/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1103 - recall: 0.9821 - precision: 0.9839 - val_loss: 0.0783 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 171/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1081 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0797 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 172/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1043 - recall: 0.9821 - precision: 0.9821 - val_loss: 0.0795 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 173/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1139 - recall: 0.9767 - precision: 0.9767 - val_loss: 0.0753 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 174/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1297 - recall: 0.9624 - precision: 0.9624 - val_loss: 0.1075 - val_recall: 0.9929 - val_precision: 0.9929
# Epoch 175/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1036 - recall: 0.9857 - precision: 0.9857 - val_loss: 0.0830 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 176/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1114 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0718 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 177/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1133 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0789 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 178/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1123 - recall: 0.9785 - precision: 0.9785 - val_loss: 0.0800 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 179/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1033 - recall: 0.9839 - precision: 0.9839 - val_loss: 0.1219 - val_recall: 0.9643 - val_precision: 0.9643
# Epoch 180/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1137 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0757 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 181/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1082 - recall: 0.9785 - precision: 0.9785 - val_loss: 0.0855 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 182/200
# 35/35 [==============================] - 2s 72ms/step - loss: 0.1102 - recall: 0.9750 - precision: 0.9767 - val_loss: 0.0760 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 183/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1076 - recall: 0.9785 - precision: 0.9785 - val_loss: 0.0698 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 184/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.1081 - recall: 0.9785 - precision: 0.9803 - val_loss: 0.0723 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 185/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1084 - recall: 0.9732 - precision: 0.9732 - val_loss: 0.0765 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 186/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1092 - recall: 0.9767 - precision: 0.9767 - val_loss: 0.0738 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 187/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1411 - recall: 0.9553 - precision: 0.9553 - val_loss: 0.1494 - val_recall: 0.9643 - val_precision: 0.9643
# Epoch 188/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1333 - recall: 0.9535 - precision: 0.9535 - val_loss: 0.0762 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 189/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1053 - recall: 0.9750 - precision: 0.9750 - val_loss: 0.0772 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 190/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1129 - recall: 0.9642 - precision: 0.9642 - val_loss: 0.0869 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 191/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1154 - recall: 0.9803 - precision: 0.9803 - val_loss: 0.0743 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 192/200
# 35/35 [==============================] - 3s 70ms/step - loss: 0.1179 - recall: 0.9678 - precision: 0.9678 - val_loss: 0.0758 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 193/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.1019 - recall: 0.9803 - precision: 0.9803 - val_loss: 0.0751 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 194/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.0974 - recall: 0.9857 - precision: 0.9875 - val_loss: 0.0721 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 195/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.0940 - recall: 0.9839 - precision: 0.9839 - val_loss: 0.0846 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 196/200
# 35/35 [==============================] - 4s 106ms/step - loss: 0.1083 - recall: 0.9785 - precision: 0.9785 - val_loss: 0.0699 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 197/200
# 35/35 [==============================] - 4s 105ms/step - loss: 0.1104 - recall: 0.9714 - precision: 0.9714 - val_loss: 0.0794 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 198/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1020 - recall: 0.9821 - precision: 0.9821 - val_loss: 0.0799 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 199/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.0957 - recall: 0.9857 - precision: 0.9857 - val_loss: 0.0683 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 200/200
# 35/35 [==============================] - 3s 77ms/step - loss: 0.1013 - recall: 0.9803 - precision: 0.9803 - val_loss: 0.0704 - val_recall: 1.0000 - val_precision: 1.0000
# 1/1 [==============================] - 1s 753ms/step
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Joerg\AppData\Local\Temp\tmpjbk49bt6\model\data\model\assets
# INFO:tensorflow:Assets written to: C:\Users\Joerg\AppData\Local\Temp\tmpjbk49bt6\model\data\model\assets
# 2023/04/08 09:09:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\Users\Joerg\anaconda3\envs\NeuralNetwork\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
import matplotlib.pyplot as plt
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    precision = list(hist.history.keys())[2]
    val_precision = list(hist.history.keys())[5]
    # Get the training loss and accuracy values from the history object
    training_loss = hist.history['loss']
    training_accuracy = hist.history[precision]

    # Get the validation loss and accuracy values from the history object
    validation_loss = hist.history['val_loss']
    validation_accuracy = hist.history[val_precision]

    # Plot the training and validation loss and accuracy on the same subplot
    plt.plot(training_loss, label='Training Loss')
    plt.plot(validation_loss, label='Validation Loss')
    plt.plot(training_accuracy, label='Training Precision')
    plt.plot(validation_accuracy, label='Validation Precision')
    plt.legend()
    plt.title('Loss and Precision over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss and Precision')
    fig = plt.gcf()
    mlflow.log_figure(fig, 'Loss and Accuracy Plot.png')
    plt.show()

# %%
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    testData = generate_dataset("test", data_classes)
    testData = batch_prefetch(testData)

    test_loss, test_recall, test_precision = model.evaluate(testData)
    mlflow.log_metric("Test Loss", test_loss)
    mlflow.log_metric("Test Precision", test_precision)
# Out:
# Sniffing Datasets: 54
# Background Datasets: 199
# Quiet Datasets: 47
# Corrected Sniffing Datasets: 47
# Corrected Background Datasets: 47
# Corrected Quiet Datasets: 47
# 9/9 [==============================] - 3s 7ms/step - loss: 0.4490 - recall: 0.7943 - precision: 0.7943

# %%
mlflow.end_run()
