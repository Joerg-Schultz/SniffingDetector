# %%
run_name = "three neurons, 80 Dense"
description = "Increased the number of neurons in the hidden layer to 80"
data_version = "0" # only to tell IDE that version is a viable
# %store -r data_version
# data_version = "dv1" # if you want to force a specific version

data_classes = ["Sniffing", "Background", "Quiet"]
correct_class_imbalance = True
epochs = 200
validation_fraction = 0.2

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout
import tensorflow_io as tfio
import tensorflow.experimental.numpy as tnp
from tensorflow.python.ops import gen_audio_ops as audio_ops
import os
import mlflow
#  enable NumPy behavior for TensorFlow:
tnp.experimental_enable_numpy_behavior()

# %%
def generate_spectrogram(file_path, label):
    # does not scale as sniffing should be the same independent of background level
    audio_tensor = tfio.audio.AudioIOTensor(file_path, dtype=tf.int16)
    audio = tf.cast(audio_tensor[:], tf.float32)
    spectrogram = audio_ops.audio_spectrogram(audio,
                                              window_size=320,
                                              stride=160,
                                              magnitude_squared=True)
    spectrogram = tf.nn.pool(
        input=tf.expand_dims(spectrogram, -1),
        window_shape=[1, 6],
        strides=[1, 6],
        pooling_type='AVG',
        padding='SAME')
    spectrogram = tf.squeeze(spectrogram, axis=0)
    # Not sure whether the log is a good idea...
    spectrogram = tnp.log10(spectrogram + 1e-6)
    return spectrogram, label

def prepare_data(dir, value):
    filePath = os.path.join(dir, "*.wav")
    files = tf.data.Dataset.list_files(filePath)
    file_count = len(files)
    #values = tf.zeros(len(files)) if value == 0 else tf.ones(len(files))
    # First neuron for Sniffing
    if value == 0:
        values = tf.concat([tf.ones(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1])], axis=1)
    elif value == 1:
        values = tf.concat([tf.zeros(shape=[file_count, 1]), tf.ones(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1])], axis=1)
    elif value == 2:
        values = tf.concat([tf.zeros(shape=[file_count, 1]), tf.zeros(shape=[file_count, 1]), tf.ones(shape=[file_count, 1])], axis=1)

    data = tf.data.Dataset.zip((files, tf.data.Dataset.from_tensor_slices(values)))
    spectrogramData = data.map(generate_spectrogram)
    return spectrogramData

def generate_dataset(train_or_test, classes):
    class_counts = []
    data_sets = []
    for index, current_class in enumerate(classes):
        current_data_dir = f"data/{train_or_test}/{current_class}"
        current_data = prepare_data(current_data_dir, index)
        data_sets.append(current_data)
        current_number = current_data.cardinality().numpy()
        class_counts.append(current_number)
        print(f"{current_class} Datasets: {current_number}")

    if correct_class_imbalance:
        smallest_data_count = min(class_counts)
        for index, data_set in enumerate(data_sets):
            corrected_data = data_set.shuffle(class_counts[index]).take(smallest_data_count)
            data_sets[index] = corrected_data
            corrected_number = corrected_data.cardinality().numpy()
            print(f"Corrected {classes[index]} Datasets: {corrected_number}")
    combined_data = data_sets[0]
    for next_data in data_sets[1:]:
        combined_data = combined_data.concatenate(next_data)
    combined_data = combined_data.cache()
    return combined_data.shuffle(buffer_size=combined_data.cardinality().numpy())

def split_validation(allData, fraction):
    numberDataSets = allData.cardinality().numpy()
    validationCount = round(numberDataSets * fraction)
    trainSet = allData.take(numberDataSets - validationCount)
    validationSet = allData.skip(numberDataSets - validationCount).take(validationCount)
    return trainSet, validationSet

def batch_prefetch(dataSet):
    dataSet = dataSet.batch(16)
    dataSet = dataSet.prefetch(8)
    return dataSet

# %%
data = generate_dataset("train", data_classes)
train, validation = split_validation(data, validation_fraction)
train = batch_prefetch(train)
validation = batch_prefetch(validation)
samples, labels = train.as_numpy_iterator().next()
inputShape = samples.shape[1:]
print(f"inputShape {inputShape}")
# Out:
# Sniffing Datasets: 261
# Background Datasets: 765
# Quiet Datasets: 233
# Corrected Sniffing Datasets: 233
# Corrected Background Datasets: 233
# Corrected Quiet Datasets: 233
# inputShape (99, 43, 1)

# %%
# need the run id to log into same run over different cells
with mlflow.start_run(run_name=run_name) as run:
    run_id = run.info.run_id
    mlflow.tensorflow.autolog()
    mlflow.log_param("data_version", data_version)
    mlflow.log_param("data classes", data_classes)
    mlflow.log_param("validation fraction", validation_fraction)
    mlflow.log_param("correct class imbalance", correct_class_imbalance)
    mlflow.log_param("Description", description)

# %%
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    model = Sequential([
        Conv2D(4, 3,
               padding='same',
               activation='relu',
               kernel_regularizer=regularizers.l2(0.001),
               name='conv_layer1',
               input_shape=inputShape),
        MaxPooling2D(name='max_pooling1', pool_size=(2,2)),
        Conv2D(4, 3,
               padding='same',
               activation='relu',
               kernel_regularizer=regularizers.l2(0.001),
               name='conv_layer2'),
        MaxPooling2D(name='max_pooling2', pool_size=(2,2)),
        Flatten(),
        Dropout(0.2),
        Dense(
            80,
            activation='relu',
            kernel_regularizer=regularizers.l2(0.001),
            name='hidden_layer1'
        ),
        Dense(
            3,
            activation='softmax',
            kernel_regularizer=regularizers.l2(0.001),
            name='output'
        )
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=[[tf.keras.metrics.Recall(),tf.keras.metrics.Precision()]])

    model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_layer1 (Conv2D)        (None, 99, 43, 4)         40
#
#  max_pooling1 (MaxPooling2D)  (None, 49, 21, 4)        0
#
#  conv_layer2 (Conv2D)        (None, 49, 21, 4)         148
#
#  max_pooling2 (MaxPooling2D)  (None, 24, 10, 4)        0
#
#  flatten_1 (Flatten)         (None, 960)               0
#
#  dropout_1 (Dropout)         (None, 960)               0
#
#  hidden_layer1 (Dense)       (None, 80)                76880
#
#  output (Dense)              (None, 3)                 243
#
# =================================================================
# Total params: 77,311
# Trainable params: 77,311
# Non-trainable params: 0
# _________________________________________________________________

# %%
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    hist = model.fit(train, epochs=epochs, validation_data=validation)
# Out:
# Epoch 1/200
# 35/35 [==============================] - 2s 21ms/step - loss: 0.8164 - recall_1: 0.2343 - precision_1: 0.4426 - val_loss: 0.6431 - val_recall_1: 0.1000 - val_precision_1: 1.0000
# Epoch 2/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.6118 - recall_1: 0.2487 - precision_1: 0.7056 - val_loss: 0.5277 - val_recall_1: 0.4000 - val_precision_1: 0.8615
# Epoch 3/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.5210 - recall_1: 0.4794 - precision_1: 0.6683 - val_loss: 0.4804 - val_recall_1: 0.5357 - val_precision_1: 0.7282
# Epoch 4/200
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4897 - recall_1: 0.5671 - precision_1: 0.6847 - val_loss: 0.4800 - val_recall_1: 0.6286 - val_precision_1: 0.6984
# Epoch 5/200
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4578 - recall_1: 0.6225 - precision_1: 0.7088 - val_loss: 0.4377 - val_recall_1: 0.6500 - val_precision_1: 0.6642
# Epoch 6/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.4355 - recall_1: 0.6601 - precision_1: 0.7015 - val_loss: 0.4071 - val_recall_1: 0.7214 - val_precision_1: 0.7266
# Epoch 7/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.4325 - recall_1: 0.6619 - precision_1: 0.6814 - val_loss: 0.4257 - val_recall_1: 0.6571 - val_precision_1: 0.7244
# Epoch 8/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.4233 - recall_1: 0.6386 - precision_1: 0.6698 - val_loss: 0.4219 - val_recall_1: 0.7000 - val_precision_1: 0.7050
# Epoch 9/200
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4175 - recall_1: 0.6708 - precision_1: 0.6970 - val_loss: 0.3997 - val_recall_1: 0.7286 - val_precision_1: 0.7338
# Epoch 10/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.4098 - recall_1: 0.6977 - precision_1: 0.7169 - val_loss: 0.3962 - val_recall_1: 0.7286 - val_precision_1: 0.7445
# Epoch 11/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.4089 - recall_1: 0.6816 - precision_1: 0.6927 - val_loss: 0.3925 - val_recall_1: 0.6571 - val_precision_1: 0.6571
# Epoch 12/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3953 - recall_1: 0.7352 - precision_1: 0.7459 - val_loss: 0.3337 - val_recall_1: 0.7929 - val_precision_1: 0.7929
# Epoch 13/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3873 - recall_1: 0.7352 - precision_1: 0.7432 - val_loss: 0.3817 - val_recall_1: 0.7500 - val_precision_1: 0.7554
# Epoch 14/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3772 - recall_1: 0.7460 - precision_1: 0.7582 - val_loss: 0.3457 - val_recall_1: 0.7857 - val_precision_1: 0.7857
# Epoch 15/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3902 - recall_1: 0.7352 - precision_1: 0.7432 - val_loss: 0.3949 - val_recall_1: 0.7071 - val_precision_1: 0.7226
# Epoch 16/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3750 - recall_1: 0.7370 - precision_1: 0.7450 - val_loss: 0.3420 - val_recall_1: 0.7714 - val_precision_1: 0.7714
# Epoch 17/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3684 - recall_1: 0.7406 - precision_1: 0.7446 - val_loss: 0.3350 - val_recall_1: 0.7929 - val_precision_1: 0.7929
# Epoch 18/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3627 - recall_1: 0.7603 - precision_1: 0.7616 - val_loss: 0.3542 - val_recall_1: 0.7357 - val_precision_1: 0.7410
# Epoch 19/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3599 - recall_1: 0.7513 - precision_1: 0.7527 - val_loss: 0.3201 - val_recall_1: 0.8286 - val_precision_1: 0.8345
# Epoch 20/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3492 - recall_1: 0.7746 - precision_1: 0.7774 - val_loss: 0.2972 - val_recall_1: 0.7857 - val_precision_1: 0.7914
# Epoch 21/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3452 - recall_1: 0.7782 - precision_1: 0.7838 - val_loss: 0.3205 - val_recall_1: 0.8429 - val_precision_1: 0.8489
# Epoch 22/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3336 - recall_1: 0.7907 - precision_1: 0.7935 - val_loss: 0.3586 - val_recall_1: 0.7500 - val_precision_1: 0.7664
# Epoch 23/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3201 - recall_1: 0.8140 - precision_1: 0.8140 - val_loss: 0.3022 - val_recall_1: 0.8786 - val_precision_1: 0.8786
# Epoch 24/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3243 - recall_1: 0.7889 - precision_1: 0.7917 - val_loss: 0.3503 - val_recall_1: 0.7857 - val_precision_1: 0.7857
# Epoch 25/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3165 - recall_1: 0.7871 - precision_1: 0.7885 - val_loss: 0.3225 - val_recall_1: 0.8143 - val_precision_1: 0.8143
# Epoch 26/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3151 - recall_1: 0.8086 - precision_1: 0.8086 - val_loss: 0.2825 - val_recall_1: 0.8357 - val_precision_1: 0.8357
# Epoch 27/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3181 - recall_1: 0.7961 - precision_1: 0.8004 - val_loss: 0.2785 - val_recall_1: 0.8643 - val_precision_1: 0.8643
# Epoch 28/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2905 - recall_1: 0.8354 - precision_1: 0.8369 - val_loss: 0.2915 - val_recall_1: 0.8786 - val_precision_1: 0.8849
# Epoch 29/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2917 - recall_1: 0.8175 - precision_1: 0.8205 - val_loss: 0.2703 - val_recall_1: 0.8786 - val_precision_1: 0.8786
# Epoch 30/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3285 - recall_1: 0.7710 - precision_1: 0.7724 - val_loss: 0.3094 - val_recall_1: 0.8000 - val_precision_1: 0.8000
# Epoch 31/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.3025 - recall_1: 0.8265 - precision_1: 0.8280 - val_loss: 0.2867 - val_recall_1: 0.8071 - val_precision_1: 0.8071
# Epoch 32/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2912 - recall_1: 0.8301 - precision_1: 0.8315 - val_loss: 0.2708 - val_recall_1: 0.8286 - val_precision_1: 0.8286
# Epoch 33/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2956 - recall_1: 0.8283 - precision_1: 0.8297 - val_loss: 0.2235 - val_recall_1: 0.9286 - val_precision_1: 0.9286
# Epoch 34/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2795 - recall_1: 0.8318 - precision_1: 0.8318 - val_loss: 0.2871 - val_recall_1: 0.8857 - val_precision_1: 0.8857
# Epoch 35/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2872 - recall_1: 0.8426 - precision_1: 0.8441 - val_loss: 0.2813 - val_recall_1: 0.7929 - val_precision_1: 0.7929
# Epoch 36/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2747 - recall_1: 0.8515 - precision_1: 0.8530 - val_loss: 0.2437 - val_recall_1: 0.9000 - val_precision_1: 0.9000
# Epoch 37/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2884 - recall_1: 0.8301 - precision_1: 0.8330 - val_loss: 0.2784 - val_recall_1: 0.8643 - val_precision_1: 0.8643
# Epoch 38/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2800 - recall_1: 0.8318 - precision_1: 0.8348 - val_loss: 0.2678 - val_recall_1: 0.8571 - val_precision_1: 0.8571
# Epoch 39/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2765 - recall_1: 0.8408 - precision_1: 0.8423 - val_loss: 0.2387 - val_recall_1: 0.8929 - val_precision_1: 0.8993
# Epoch 40/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2693 - recall_1: 0.8533 - precision_1: 0.8548 - val_loss: 0.2493 - val_recall_1: 0.8857 - val_precision_1: 0.8857
# Epoch 41/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2692 - recall_1: 0.8444 - precision_1: 0.8474 - val_loss: 0.2385 - val_recall_1: 0.8857 - val_precision_1: 0.8857
# Epoch 42/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2674 - recall_1: 0.8479 - precision_1: 0.8510 - val_loss: 0.2669 - val_recall_1: 0.8429 - val_precision_1: 0.8429
# Epoch 43/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2534 - recall_1: 0.8623 - precision_1: 0.8623 - val_loss: 0.1955 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 44/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2896 - recall_1: 0.8408 - precision_1: 0.8423 - val_loss: 0.2263 - val_recall_1: 0.9143 - val_precision_1: 0.9143
# Epoch 45/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2627 - recall_1: 0.8444 - precision_1: 0.8505 - val_loss: 0.2498 - val_recall_1: 0.8786 - val_precision_1: 0.8786
# Epoch 46/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2637 - recall_1: 0.8551 - precision_1: 0.8551 - val_loss: 0.2586 - val_recall_1: 0.8500 - val_precision_1: 0.8500
# Epoch 47/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2579 - recall_1: 0.8587 - precision_1: 0.8618 - val_loss: 0.1898 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 48/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2544 - recall_1: 0.8372 - precision_1: 0.8387 - val_loss: 0.2255 - val_recall_1: 0.9071 - val_precision_1: 0.9071
# Epoch 49/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2591 - recall_1: 0.8497 - precision_1: 0.8513 - val_loss: 0.2288 - val_recall_1: 0.8500 - val_precision_1: 0.8500
# Epoch 50/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2400 - recall_1: 0.8712 - precision_1: 0.8712 - val_loss: 0.2078 - val_recall_1: 0.9143 - val_precision_1: 0.9143
# Epoch 51/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2317 - recall_1: 0.8837 - precision_1: 0.8869 - val_loss: 0.1948 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 52/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2514 - recall_1: 0.8676 - precision_1: 0.8692 - val_loss: 0.2259 - val_recall_1: 0.8857 - val_precision_1: 0.8857
# Epoch 53/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2686 - recall_1: 0.8444 - precision_1: 0.8459 - val_loss: 0.2166 - val_recall_1: 0.8929 - val_precision_1: 0.8993
# Epoch 54/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2415 - recall_1: 0.8712 - precision_1: 0.8712 - val_loss: 0.2625 - val_recall_1: 0.8786 - val_precision_1: 0.8786
# Epoch 55/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2444 - recall_1: 0.8748 - precision_1: 0.8748 - val_loss: 0.2254 - val_recall_1: 0.8857 - val_precision_1: 0.8857
# Epoch 56/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2826 - recall_1: 0.8265 - precision_1: 0.8265 - val_loss: 0.1878 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 57/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2481 - recall_1: 0.8712 - precision_1: 0.8712 - val_loss: 0.2418 - val_recall_1: 0.8500 - val_precision_1: 0.8500
# Epoch 58/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2405 - recall_1: 0.8605 - precision_1: 0.8620 - val_loss: 0.2340 - val_recall_1: 0.8786 - val_precision_1: 0.8786
# Epoch 59/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2526 - recall_1: 0.8676 - precision_1: 0.8676 - val_loss: 0.2136 - val_recall_1: 0.8857 - val_precision_1: 0.8857
# Epoch 60/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2643 - recall_1: 0.8479 - precision_1: 0.8495 - val_loss: 0.2078 - val_recall_1: 0.9143 - val_precision_1: 0.9143
# Epoch 61/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2494 - recall_1: 0.8569 - precision_1: 0.8569 - val_loss: 0.2225 - val_recall_1: 0.9071 - val_precision_1: 0.9071
# Epoch 62/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2580 - recall_1: 0.8462 - precision_1: 0.8477 - val_loss: 0.2423 - val_recall_1: 0.8857 - val_precision_1: 0.8921
# Epoch 63/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2483 - recall_1: 0.8533 - precision_1: 0.8548 - val_loss: 0.2124 - val_recall_1: 0.9143 - val_precision_1: 0.9143
# Epoch 64/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2305 - recall_1: 0.8766 - precision_1: 0.8766 - val_loss: 0.2095 - val_recall_1: 0.9286 - val_precision_1: 0.9286
# Epoch 65/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2405 - recall_1: 0.8730 - precision_1: 0.8730 - val_loss: 0.2081 - val_recall_1: 0.9000 - val_precision_1: 0.9000
# Epoch 66/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2504 - recall_1: 0.8569 - precision_1: 0.8584 - val_loss: 0.1961 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 67/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2280 - recall_1: 0.8748 - precision_1: 0.8748 - val_loss: 0.2064 - val_recall_1: 0.8929 - val_precision_1: 0.8929
# Epoch 68/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2321 - recall_1: 0.8640 - precision_1: 0.8640 - val_loss: 0.2026 - val_recall_1: 0.9286 - val_precision_1: 0.9286
# Epoch 69/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2276 - recall_1: 0.8873 - precision_1: 0.8873 - val_loss: 0.1873 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 70/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2323 - recall_1: 0.8784 - precision_1: 0.8815 - val_loss: 0.2259 - val_recall_1: 0.8857 - val_precision_1: 0.8857
# Epoch 71/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2368 - recall_1: 0.8676 - precision_1: 0.8692 - val_loss: 0.1910 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 72/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2278 - recall_1: 0.8891 - precision_1: 0.8923 - val_loss: 0.1890 - val_recall_1: 0.9214 - val_precision_1: 0.9214
# Epoch 73/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2329 - recall_1: 0.8640 - precision_1: 0.8640 - val_loss: 0.2112 - val_recall_1: 0.8929 - val_precision_1: 0.8993
# Epoch 74/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2293 - recall_1: 0.8819 - precision_1: 0.8819 - val_loss: 0.1653 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 75/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1946 - recall_1: 0.9195 - precision_1: 0.9195 - val_loss: 0.1801 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 76/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2248 - recall_1: 0.8855 - precision_1: 0.8871 - val_loss: 0.1924 - val_recall_1: 0.9429 - val_precision_1: 0.9429
# Epoch 77/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2099 - recall_1: 0.8945 - precision_1: 0.8945 - val_loss: 0.1917 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 78/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1993 - recall_1: 0.9213 - precision_1: 0.9213 - val_loss: 0.1558 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 79/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2216 - recall_1: 0.8855 - precision_1: 0.8855 - val_loss: 0.1811 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 80/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2121 - recall_1: 0.9016 - precision_1: 0.9032 - val_loss: 0.1682 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 81/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2198 - recall_1: 0.8748 - precision_1: 0.8748 - val_loss: 0.1820 - val_recall_1: 0.9000 - val_precision_1: 0.9000
# Epoch 82/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2101 - recall_1: 0.8855 - precision_1: 0.8855 - val_loss: 0.1438 - val_recall_1: 0.9714 - val_precision_1: 0.9714
# Epoch 83/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2193 - recall_1: 0.8855 - precision_1: 0.8855 - val_loss: 0.1692 - val_recall_1: 0.9643 - val_precision_1: 0.9643
# Epoch 84/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2141 - recall_1: 0.8980 - precision_1: 0.8980 - val_loss: 0.1516 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 85/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2026 - recall_1: 0.9016 - precision_1: 0.9032 - val_loss: 0.1806 - val_recall_1: 0.9000 - val_precision_1: 0.9000
# Epoch 86/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2111 - recall_1: 0.9016 - precision_1: 0.9016 - val_loss: 0.1540 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 87/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.2005 - recall_1: 0.9106 - precision_1: 0.9138 - val_loss: 0.1965 - val_recall_1: 0.9286 - val_precision_1: 0.9286
# Epoch 88/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1859 - recall_1: 0.9231 - precision_1: 0.9247 - val_loss: 0.2011 - val_recall_1: 0.9214 - val_precision_1: 0.9214
# Epoch 89/200
# 35/35 [==============================] - 1s 14ms/step - loss: 0.2072 - recall_1: 0.9070 - precision_1: 0.9070 - val_loss: 0.1474 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 90/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1970 - recall_1: 0.9195 - precision_1: 0.9211 - val_loss: 0.1573 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 91/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1943 - recall_1: 0.9249 - precision_1: 0.9249 - val_loss: 0.1952 - val_recall_1: 0.9214 - val_precision_1: 0.9214
# Epoch 92/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1961 - recall_1: 0.9177 - precision_1: 0.9177 - val_loss: 0.1670 - val_recall_1: 0.9714 - val_precision_1: 0.9714
# Epoch 93/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2066 - recall_1: 0.9123 - precision_1: 0.9123 - val_loss: 0.1614 - val_recall_1: 0.9643 - val_precision_1: 0.9643
# Epoch 94/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1968 - recall_1: 0.9123 - precision_1: 0.9123 - val_loss: 0.1728 - val_recall_1: 0.9286 - val_precision_1: 0.9286
# Epoch 95/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.2022 - recall_1: 0.9284 - precision_1: 0.9318 - val_loss: 0.1727 - val_recall_1: 0.9071 - val_precision_1: 0.9071
# Epoch 96/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1962 - recall_1: 0.9267 - precision_1: 0.9267 - val_loss: 0.1452 - val_recall_1: 0.9571 - val_precision_1: 0.9571
# Epoch 97/200
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1961 - recall_1: 0.9249 - precision_1: 0.9249 - val_loss: 0.1480 - val_recall_1: 0.9714 - val_precision_1: 0.9714
# Epoch 98/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1963 - recall_1: 0.9123 - precision_1: 0.9123 - val_loss: 0.1575 - val_recall_1: 0.9786 - val_precision_1: 0.9786
# Epoch 99/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1832 - recall_1: 0.9338 - precision_1: 0.9338 - val_loss: 0.1494 - val_recall_1: 0.9571 - val_precision_1: 0.9571
# Epoch 100/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1647 - recall_1: 0.9481 - precision_1: 0.9481 - val_loss: 0.1399 - val_recall_1: 0.9571 - val_precision_1: 0.9571
# Epoch 101/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1663 - recall_1: 0.9445 - precision_1: 0.9462 - val_loss: 0.1300 - val_recall_1: 0.9714 - val_precision_1: 0.9714
# Epoch 102/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1711 - recall_1: 0.9374 - precision_1: 0.9408 - val_loss: 0.1106 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 103/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1784 - recall_1: 0.9284 - precision_1: 0.9284 - val_loss: 0.1439 - val_recall_1: 0.9643 - val_precision_1: 0.9643
# Epoch 104/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1896 - recall_1: 0.9213 - precision_1: 0.9213 - val_loss: 0.1659 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 105/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1564 - recall_1: 0.9463 - precision_1: 0.9463 - val_loss: 0.1765 - val_recall_1: 0.9286 - val_precision_1: 0.9286
# Epoch 106/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1837 - recall_1: 0.9320 - precision_1: 0.9320 - val_loss: 0.1340 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 107/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1601 - recall_1: 0.9589 - precision_1: 0.9589 - val_loss: 0.1626 - val_recall_1: 0.9357 - val_precision_1: 0.9357
# Epoch 108/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1667 - recall_1: 0.9463 - precision_1: 0.9463 - val_loss: 0.1582 - val_recall_1: 0.9643 - val_precision_1: 0.9643
# Epoch 109/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1576 - recall_1: 0.9571 - precision_1: 0.9571 - val_loss: 0.1146 - val_recall_1: 0.9714 - val_precision_1: 0.9714
# Epoch 110/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1642 - recall_1: 0.9445 - precision_1: 0.9445 - val_loss: 0.1181 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 111/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1560 - recall_1: 0.9571 - precision_1: 0.9571 - val_loss: 0.1255 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 112/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1439 - recall_1: 0.9589 - precision_1: 0.9589 - val_loss: 0.1245 - val_recall_1: 0.9714 - val_precision_1: 0.9714
# Epoch 113/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1527 - recall_1: 0.9553 - precision_1: 0.9553 - val_loss: 0.1104 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 114/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1509 - recall_1: 0.9463 - precision_1: 0.9463 - val_loss: 0.1053 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 115/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1560 - recall_1: 0.9535 - precision_1: 0.9535 - val_loss: 0.1087 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 116/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1437 - recall_1: 0.9589 - precision_1: 0.9589 - val_loss: 0.1653 - val_recall_1: 0.9500 - val_precision_1: 0.9500
# Epoch 117/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1434 - recall_1: 0.9571 - precision_1: 0.9571 - val_loss: 0.1059 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 118/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1528 - recall_1: 0.9481 - precision_1: 0.9481 - val_loss: 0.0983 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 119/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1424 - recall_1: 0.9642 - precision_1: 0.9642 - val_loss: 0.1018 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 120/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1214 - recall_1: 0.9803 - precision_1: 0.9803 - val_loss: 0.1004 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 121/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1276 - recall_1: 0.9696 - precision_1: 0.9713 - val_loss: 0.1216 - val_recall_1: 0.9786 - val_precision_1: 0.9786
# Epoch 122/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1369 - recall_1: 0.9535 - precision_1: 0.9535 - val_loss: 0.0994 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 123/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1328 - recall_1: 0.9642 - precision_1: 0.9642 - val_loss: 0.1011 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 124/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1177 - recall_1: 0.9785 - precision_1: 0.9785 - val_loss: 0.0948 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 125/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1297 - recall_1: 0.9785 - precision_1: 0.9785 - val_loss: 0.1054 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 126/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1381 - recall_1: 0.9535 - precision_1: 0.9535 - val_loss: 0.1149 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 127/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1425 - recall_1: 0.9624 - precision_1: 0.9624 - val_loss: 0.1064 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 128/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1192 - recall_1: 0.9785 - precision_1: 0.9785 - val_loss: 0.0956 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 129/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1431 - recall_1: 0.9589 - precision_1: 0.9589 - val_loss: 0.0992 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 130/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1367 - recall_1: 0.9589 - precision_1: 0.9589 - val_loss: 0.0970 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 131/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1197 - recall_1: 0.9803 - precision_1: 0.9803 - val_loss: 0.1371 - val_recall_1: 0.9571 - val_precision_1: 0.9571
# Epoch 132/200
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1293 - recall_1: 0.9696 - precision_1: 0.9696 - val_loss: 0.1243 - val_recall_1: 0.9786 - val_precision_1: 0.9786
# Epoch 133/200
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1321 - recall_1: 0.9696 - precision_1: 0.9696 - val_loss: 0.1072 - val_recall_1: 0.9786 - val_precision_1: 0.9786
# Epoch 134/200
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1229 - recall_1: 0.9732 - precision_1: 0.9732 - val_loss: 0.0934 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 135/200
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1224 - recall_1: 0.9678 - precision_1: 0.9695 - val_loss: 0.0883 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 136/200
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1248 - recall_1: 0.9696 - precision_1: 0.9696 - val_loss: 0.0910 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 137/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1187 - recall_1: 0.9714 - precision_1: 0.9731 - val_loss: 0.0911 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 138/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1096 - recall_1: 0.9803 - precision_1: 0.9803 - val_loss: 0.0898 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 139/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1104 - recall_1: 0.9821 - precision_1: 0.9821 - val_loss: 0.0906 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 140/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1115 - recall_1: 0.9821 - precision_1: 0.9821 - val_loss: 0.1049 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 141/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1206 - recall_1: 0.9678 - precision_1: 0.9678 - val_loss: 0.0988 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 142/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1167 - recall_1: 0.9750 - precision_1: 0.9750 - val_loss: 0.1181 - val_recall_1: 0.9714 - val_precision_1: 0.9714
# Epoch 143/200
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1224 - recall_1: 0.9678 - precision_1: 0.9678 - val_loss: 0.0864 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 144/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1143 - recall_1: 0.9750 - precision_1: 0.9750 - val_loss: 0.0902 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 145/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1037 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0928 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 146/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0994 - recall_1: 0.9893 - precision_1: 0.9893 - val_loss: 0.0753 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 147/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1083 - recall_1: 0.9785 - precision_1: 0.9785 - val_loss: 0.0849 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 148/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1130 - recall_1: 0.9750 - precision_1: 0.9750 - val_loss: 0.0798 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 149/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1126 - recall_1: 0.9785 - precision_1: 0.9785 - val_loss: 0.0923 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 150/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1062 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0783 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 151/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1091 - recall_1: 0.9767 - precision_1: 0.9767 - val_loss: 0.0878 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 152/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1165 - recall_1: 0.9767 - precision_1: 0.9767 - val_loss: 0.0856 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 153/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1119 - recall_1: 0.9803 - precision_1: 0.9803 - val_loss: 0.0886 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 154/200
# 35/35 [==============================] - 1s 14ms/step - loss: 0.1124 - recall_1: 0.9857 - precision_1: 0.9857 - val_loss: 0.0783 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 155/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1198 - recall_1: 0.9678 - precision_1: 0.9695 - val_loss: 0.0986 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 156/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1285 - recall_1: 0.9642 - precision_1: 0.9659 - val_loss: 0.0844 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 157/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1044 - recall_1: 0.9839 - precision_1: 0.9839 - val_loss: 0.0809 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 158/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1011 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0794 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 159/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1039 - recall_1: 0.9821 - precision_1: 0.9821 - val_loss: 0.0807 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 160/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1073 - recall_1: 0.9803 - precision_1: 0.9803 - val_loss: 0.0777 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 161/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1115 - recall_1: 0.9732 - precision_1: 0.9732 - val_loss: 0.0870 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 162/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0945 - recall_1: 0.9893 - precision_1: 0.9893 - val_loss: 0.0731 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 163/200
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0983 - recall_1: 0.9857 - precision_1: 0.9857 - val_loss: 0.0863 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 164/200
# 35/35 [==============================] - 1s 18ms/step - loss: 0.1004 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0783 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 165/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1056 - recall_1: 0.9821 - precision_1: 0.9821 - val_loss: 0.0920 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 166/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1144 - recall_1: 0.9767 - precision_1: 0.9767 - val_loss: 0.0847 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 167/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1037 - recall_1: 0.9821 - precision_1: 0.9821 - val_loss: 0.0800 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 168/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0955 - recall_1: 0.9911 - precision_1: 0.9911 - val_loss: 0.0765 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 169/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1023 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0841 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 170/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1049 - recall_1: 0.9803 - precision_1: 0.9803 - val_loss: 0.0906 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 171/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0994 - recall_1: 0.9893 - precision_1: 0.9893 - val_loss: 0.1032 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 172/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1265 - recall_1: 0.9589 - precision_1: 0.9589 - val_loss: 0.0797 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 173/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0946 - recall_1: 0.9911 - precision_1: 0.9911 - val_loss: 0.0739 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 174/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0919 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0750 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 175/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0975 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0764 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 176/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1039 - recall_1: 0.9767 - precision_1: 0.9767 - val_loss: 0.0775 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 177/200
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0883 - recall_1: 0.9928 - precision_1: 0.9928 - val_loss: 0.0714 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 178/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0997 - recall_1: 0.9821 - precision_1: 0.9821 - val_loss: 0.0855 - val_recall_1: 0.9857 - val_precision_1: 0.9857
# Epoch 179/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1028 - recall_1: 0.9839 - precision_1: 0.9839 - val_loss: 0.0846 - val_recall_1: 0.9929 - val_precision_1: 0.9929
# Epoch 180/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0988 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0785 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 181/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1044 - recall_1: 0.9803 - precision_1: 0.9803 - val_loss: 0.0717 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 182/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1000 - recall_1: 0.9928 - precision_1: 0.9928 - val_loss: 0.0801 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 183/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1060 - recall_1: 0.9857 - precision_1: 0.9857 - val_loss: 0.0789 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 184/200
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0976 - recall_1: 0.9857 - precision_1: 0.9857 - val_loss: 0.0754 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 185/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0881 - recall_1: 0.9911 - precision_1: 0.9911 - val_loss: 0.0692 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 186/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0887 - recall_1: 0.9946 - precision_1: 0.9946 - val_loss: 0.0706 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 187/200
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1197 - recall_1: 0.9767 - precision_1: 0.9767 - val_loss: 0.0773 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 188/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1050 - recall_1: 0.9732 - precision_1: 0.9732 - val_loss: 0.0854 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 189/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1044 - recall_1: 0.9767 - precision_1: 0.9767 - val_loss: 0.0736 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 190/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0992 - recall_1: 0.9857 - precision_1: 0.9857 - val_loss: 0.0778 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 191/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1003 - recall_1: 0.9839 - precision_1: 0.9839 - val_loss: 0.0752 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 192/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0889 - recall_1: 0.9911 - precision_1: 0.9911 - val_loss: 0.0709 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 193/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0911 - recall_1: 0.9911 - precision_1: 0.9911 - val_loss: 0.0800 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 194/200
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0944 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0743 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 195/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0834 - recall_1: 0.9946 - precision_1: 0.9946 - val_loss: 0.0688 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 196/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0966 - recall_1: 0.9785 - precision_1: 0.9785 - val_loss: 0.0804 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 197/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0881 - recall_1: 0.9875 - precision_1: 0.9875 - val_loss: 0.0674 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 198/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0841 - recall_1: 0.9928 - precision_1: 0.9928 - val_loss: 0.0702 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 199/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0814 - recall_1: 0.9946 - precision_1: 0.9946 - val_loss: 0.0685 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# Epoch 200/200
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1006 - recall_1: 0.9839 - precision_1: 0.9839 - val_loss: 0.0721 - val_recall_1: 1.0000 - val_precision_1: 1.0000
# 1/1 [==============================] - 0s 68ms/step
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Joerg\AppData\Local\Temp\tmpwwkuf_cv\model\data\model\assets
# INFO:tensorflow:Assets written to: C:\Users\Joerg\AppData\Local\Temp\tmpwwkuf_cv\model\data\model\assets

# %%
import matplotlib.pyplot as plt
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    precision = list(hist.history.keys())[2]
    val_precision = list(hist.history.keys())[5]
    # Get the training loss and accuracy values from the history object
    training_loss = hist.history['loss']
    training_accuracy = hist.history[precision]

    # Get the validation loss and accuracy values from the history object
    validation_loss = hist.history['val_loss']
    validation_accuracy = hist.history[val_precision]

    # Plot the training and validation loss and accuracy on the same subplot
    plt.plot(training_loss, label='Training Loss')
    plt.plot(validation_loss, label='Validation Loss')
    plt.plot(training_accuracy, label='Training Precision')
    plt.plot(validation_accuracy, label='Validation Precision')
    plt.legend()
    plt.title('Loss and Precision over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss and Precision')
    fig = plt.gcf()
    mlflow.log_figure(fig, 'Loss and Accuracy Plot.png')
    plt.show()

# %%
with mlflow.start_run(run_id=run_id, run_name=run_name) as run:
    testData = generate_dataset("test", data_classes)
    testData = batch_prefetch(testData)

    test_loss, test_recall, test_precision = model.evaluate(testData)
    mlflow.log_metric("Test Loss", test_loss)
    mlflow.log_metric("Test Precision", test_precision)
# Out:
# Sniffing Datasets: 54
# Background Datasets: 199
# Quiet Datasets: 47
# Corrected Sniffing Datasets: 47
# Corrected Background Datasets: 47
# Corrected Quiet Datasets: 47
# 9/9 [==============================] - 1s 7ms/step - loss: 0.3740 - recall_1: 0.7872 - precision_1: 0.7872

# %%
mlflow.end_run()
